# %%
import sys
import cv2
sys.path.insert(1, '../../src/')
import matplotlib.pyplot as plt
from wholebodypose.models.mediapipe.model import MediapipeModel
from wholebodypose.models.mediapipe.map_mp2coco import MP2COCO
from wholebodypose.utils.vision import DrawerPose
draw_skeleton = DrawerPose()

# %%
import copy 
import time

maper = MP2COCO()

# %% [markdown]
# # Read image

# %%
img     = cv2.imread("../../data/images/image_1.jpeg")
print(img.shape)
img_rgb = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)


fig=plt.figure(figsize=(10,5))
plt.imshow(img_rgb)
plt.show()
# Out:
# (2083, 3380, 3)

# %% [markdown]
# # Load model

# %% [markdown]
#     face_config = {
#         'min_detection_confidence': 0.5,
#         'min_tracking_confidence': 0.5,
#         'max_num_faces': 1,
#         'refine_landmarks':True
#     }
#
#     hands_config = {
#         'min_detection_confidence': 0.3,
#         'min_tracking_confidence': 0.3,
#         'max_num_hands': 2,
#         'model_complexity': 1
#     }
#
#     pose_config = {
#         'min_detection_confidence': 0.3,
#         'min_tracking_confidence': 0.3,
#         'model_complexity': 2,
#         'smooth_landmarks':True,
#         'enable_segmentation':False,
#         'smooth_segmentation':True
#     }
#
#     model = MediapipeModel(models= ['hand', 'face', 'pose'], image_mode= True,
#                     face_config= face_config, hands_config=hands_config, pose_config=pose_config)

# %%
model = MediapipeModel()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1767324213.555778 3570097 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1767324213.700495 3570673 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.172.08), renderer: NVIDIA A100 80GB PCIe/PCIe/SSE2
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# I0000 00:00:1767324213.713739 3570097 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1767324213.749420 3570727 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.172.08), renderer: NVIDIA A100 80GB PCIe/PCIe/SSE2
# Downloading model to /home/va0831/slr/end_slr/lib64/python3.9/site-packages/mediapipe/modules/pose_landmark/pose_landmark_heavy.tflite
# I0000 00:00:1767324214.996283 3570097 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1767324215.034704 3570800 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.172.08), renderer: NVIDIA A100 80GB PCIe/PCIe/SSE2

# %%
results = model.predict(frame_rgb=img_rgb)

# %%
ldk_config = {
    'circle_radius':5,
    'thickness':4,
    'color':(255,0,0)
}
con_config = {
    'circle_radius':5,
    'thickness':12,
    'color':(255,128,0)
    #'color':(0,255,255)
}

img_rgb_new = model.draw_mediapipe(img_rgb,results,landmark_config=ldk_config,connection_config=con_config)
fig=plt.figure(figsize=(10,5))
plt.imshow(img_rgb_new)
plt.show()

# %%
start = time.time()
keypoints_new, scores_new = maper.process(img_rgb,results)
print("Time:",time.time()-start)



img_rgb_new2 = copy.deepcopy(img_rgb)
img_rgb_new2 = draw_skeleton(img_rgb_new2, keypoints_new, scores_new, kpt_thr=0.5,
                             line_width=18,radius=12)

fig=plt.figure(figsize=(10,5))
plt.imshow(img_rgb_new2)
plt.show()
# Out:
# Time: 0.0025572776794433594

# %%
model = MediapipeModel(mode_coco=True,use_thresholding=True,kpt_thr=0.5)
keypoints_new, scores_new = model.predict(frame_rgb=img_rgb)

img_rgb_new2 = copy.deepcopy(img_rgb)
img_rgb_new2 = draw_skeleton(img_rgb_new2, keypoints_new, scores_new, kpt_thr=0.5,
                             line_width=18,radius=12)

fig=plt.figure(figsize=(10,5))
plt.imshow(img_rgb_new2)
plt.show()
# Out:
# I0000 00:00:1767324216.971597 3570097 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1767324217.013844 3570856 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.172.08), renderer: NVIDIA A100 80GB PCIe/PCIe/SSE2
# I0000 00:00:1767324217.024441 3570097 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1767324217.059681 3570910 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.172.08), renderer: NVIDIA A100 80GB PCIe/PCIe/SSE2
# I0000 00:00:1767324217.076211 3570097 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1767324217.112412 3570983 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.172.08), renderer: NVIDIA A100 80GB PCIe/PCIe/SSE2

# %%
keypoints_new.shape,scores_new.shape
# Out:
# ((1, 133, 2), (1, 133))

# %%
type(keypoints_new),type(scores_new)
# Out:
# (numpy.ndarray, numpy.ndarray)
